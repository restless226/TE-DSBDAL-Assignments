# %% [markdown]
# # Assignment 4
# ### Author: Rohit Pendse
# ### Roll No: 33358
# ## Problem Statement
# ### Perform the following operations using Python on the Facebook metrics data sets
# 1. Create data subsets
# 2. Merge Data
# 3. Sort Data
# 4. Transposing Data
# 5. Shape and reshape Data

# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
# Reading the dataset
dataset = pd.read_csv(r'D:\ROHIT\TE Assignments SEM II\DSBDAL\33358_Rohit\Assignment4\Facebook_metrics_dataset.csv', sep=";")
dataset.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# 4                                              3200
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
# 4                                                396
#
#    comment    like  share  Total Interactions
# 0        4    79.0   17.0                 100
# 1        5   130.0   29.0                 164
# 2        0    66.0   14.0                  80
# 3       58  1572.0  147.0                1777
# 4       19   325.0   49.0                 393

# %%
# Shape of the dataset
dataset.shape
# Out:
# (500, 19)

# %%
dataset.describe(include="all")
# Out:
#         Page total likes   Type    Category  Post Month  Post Weekday  \
# count         500.000000    500  500.000000  500.000000    500.000000
# unique               NaN      4         NaN         NaN           NaN
# top                  NaN  Photo         NaN         NaN           NaN
# freq                 NaN    426         NaN         NaN           NaN
# mean       123194.176000    NaN    1.880000    7.038000      4.150000
# std         16272.813214    NaN    0.852675    3.307936      2.030701
# min         81370.000000    NaN    1.000000    1.000000      1.000000
# 25%        112676.000000    NaN    1.000000    4.000000      2.000000
# 50%        129600.000000    NaN    2.000000    7.000000      4.000000
# 75%        136393.000000    NaN    3.000000   10.000000      6.000000
# max        139441.000000    NaN    3.000000   12.000000      7.000000
#
#          Post Hour        Paid  Lifetime Post Total Reach  \
# count   500.000000  499.000000                  500.00000
# unique         NaN         NaN                        NaN
# top            NaN         NaN                        NaN
# freq           NaN         NaN                        NaN
# mean      7.840000    0.278557                13903.36000
# std       4.368589    0.448739                22740.78789
# min       1.000000    0.000000                  238.00000
# 25%       3.000000    0.000000                 3315.00000
# 50%       9.000000    0.000000                 5281.00000
# 75%      11.000000    1.000000                13168.00000
# max      23.000000    1.000000               180480.00000
#
#         Lifetime Post Total Impressions  Lifetime Engaged Users  \
# count                      5.000000e+02              500.000000
# unique                              NaN                     NaN
# top                                 NaN                     NaN
# freq                                NaN                     NaN
# mean                       2.958595e+04              920.344000
# std                        7.680325e+04              985.016636
# min                        5.700000e+02                9.000000
# 25%                        5.694750e+03              393.750000
# 50%                        9.051000e+03              625.500000
# 75%                        2.208550e+04             1062.000000
# max                        1.110282e+06            11452.000000
#
#         Lifetime Post Consumers  Lifetime Post Consumptions  \
# count                500.000000                  500.000000
# unique                      NaN                         NaN
# top                         NaN                         NaN
# freq                        NaN                         NaN
# mean                 798.772000                 1415.130000
# std                  882.505013                 2000.594118
# min                    9.000000                    9.000000
# 25%                  332.500000                  509.250000
# 50%                  551.500000                  851.000000
# 75%                  955.500000                 1463.000000
# max                11328.000000                19779.000000
#
#         Lifetime Post Impressions by people who have liked your Page  \
# count                                        5.000000e+02
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                         1.676638e+04
# std                                          5.979102e+04
# min                                          5.670000e+02
# 25%                                          3.969750e+03
# 50%                                          6.255500e+03
# 75%                                          1.486050e+04
# max                                          1.107833e+06
#
#         Lifetime Post reach by people who like your Page  \
# count                                         500.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                         6585.488000
# std                                          7682.009405
# min                                           236.000000
# 25%                                          2181.500000
# 50%                                          3417.000000
# 75%                                          7989.000000
# max                                         51456.000000
#
#         Lifetime People who have liked your Page and engaged with your post  \
# count                                          500.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           609.986000
# std                                            612.725618
# min                                              9.000000
# 25%                                            291.000000
# 50%                                            412.000000
# 75%                                            656.250000
# max                                           4376.000000
#
#           comment         like       share  Total Interactions
# count   500.00000   499.000000  496.000000          500.000000
# unique        NaN          NaN         NaN                 NaN
# top           NaN          NaN         NaN                 NaN
# freq          NaN          NaN         NaN                 NaN
# mean      7.48200   177.945892   27.266129          212.120000
# std      21.18091   323.398742   42.613292          380.233118
# min       0.00000     0.000000    0.000000            0.000000
# 25%       1.00000    56.500000   10.000000           71.000000
# 50%       3.00000   101.000000   19.000000          123.500000
# 75%       7.00000   187.500000   32.250000          228.500000
# max     372.00000  5172.000000  790.000000         6334.000000

# %%
dataset.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# Lifetime Post Impressions by people who have liked your Page             int64
# Lifetime Post reach by people who like your Page                         int64
# Lifetime People who have liked your Page and engaged with your post      int64
# comment                                                                  int64
# like                                                                   float64
# share                                                                  float64
# Total Interactions                                                       int64
# dtype: object

# %% [markdown]
# ## Preprocessing

# %%
# checking for null values
dataset.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# Lifetime Post reach by people who like your Page                       0
# Lifetime People who have liked your Page and engaged with your post    0
# comment                                                                0
# like                                                                   1
# share                                                                  4
# Total Interactions                                                     0
# dtype: int64

# %%
# Dropping rows with null values
dataset = dataset.dropna()
dataset.shape
# Out:
# (495, 19)

# %%
# Testing data for null values
dataset.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# Lifetime Post reach by people who like your Page                       0
# Lifetime People who have liked your Page and engaged with your post    0
# comment                                                                0
# like                                                                   0
# share                                                                  0
# Total Interactions                                                     0
# dtype: int64

# %% [markdown]
# ## Generating subsets on the basis of type

# %%
# identifying unique values for column "Type"
dataset["Type"].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %% [markdown]
# ## Generating subsets

# %%
photo_subset = dataset[dataset["Type"] == "Photo"]
status_subset = dataset[dataset["Type"] == "Status"]
link_subset = dataset[dataset["Type"] == "Link"]
video_subset = dataset[dataset["Type"] == "Video"]

# %% [markdown]
# ## Shape of subsets

# %%
print("Photo Subset shape  : ", photo_subset.shape)
print("Status Subset shape : ", status_subset.shape)
print("Link Subset shape   : ", link_subset.shape)
print("Video Subset shape  : ", video_subset.shape)
# Out:
# Photo Subset shape  :  (421, 19)
# Status Subset shape :  (45, 19)
# Link Subset shape   :  (22, 19)
# Video Subset shape  :  (7, 19)

# %% [markdown]
# # Analysing Photos subset

# %%
# Statistical description of numerical subset
photo_subset.describe(include="all")
# Out:
#         Page total likes   Type    Category  Post Month  Post Weekday  \
# count         421.000000    421  421.000000  421.000000    421.000000
# unique               NaN      1         NaN         NaN           NaN
# top                  NaN  Photo         NaN         NaN           NaN
# freq                 NaN    421         NaN         NaN           NaN
# mean       122319.612827    NaN    1.926366    6.790974      4.087886
# std         16242.669134    NaN    0.884681    3.228447      2.056203
# min         81370.000000    NaN    1.000000    1.000000      1.000000
# 25%        109670.000000    NaN    1.000000    4.000000      2.000000
# 50%        128032.000000    NaN    2.000000    7.000000      4.000000
# 75%        136013.000000    NaN    3.000000   10.000000      6.000000
# max        139441.000000    NaN    3.000000   12.000000      7.000000
#
#          Post Hour        Paid  Lifetime Post Total Reach  \
# count   421.000000  421.000000                 421.000000
# unique         NaN         NaN                        NaN
# top            NaN         NaN                        NaN
# freq           NaN         NaN                        NaN
# mean      8.004751    0.282660               13275.389549
# std       4.432561    0.450828               22977.950816
# min       1.000000    0.000000                 238.000000
# 25%       3.000000    0.000000                3110.000000
# 50%       9.000000    0.000000                4708.000000
# 75%      11.000000    1.000000               10844.000000
# max      23.000000    1.000000              180480.000000
#
#         Lifetime Post Total Impressions  Lifetime Engaged Users  \
# count                      4.210000e+02              421.000000
# unique                              NaN                     NaN
# top                                 NaN                     NaN
# freq                                NaN                     NaN
# mean                       2.930615e+04              825.368171
# std                        8.138706e+04              871.390487
# min                        5.700000e+02                9.000000
# 25%                        5.439000e+03              421.000000
# 50%                        8.198000e+03              612.000000
# 75%                        1.744200e+04              951.000000
# max                        1.110282e+06            11452.000000
#
#         Lifetime Post Consumers  Lifetime Post Consumptions  \
# count                421.000000                  421.000000
# unique                      NaN                         NaN
# top                         NaN                         NaN
# freq                        NaN                         NaN
# mean                 695.475059                 1310.334917
# std                  734.384315                 1974.750382
# min                    9.000000                    9.000000
# 25%                  337.000000                  521.000000
# 50%                  539.000000                  834.000000
# 75%                  837.000000                 1336.000000
# max                11328.000000                19779.000000
#
#         Lifetime Post Impressions by people who have liked your Page  \
# count                                        4.210000e+02
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                         1.659465e+04
# std                                          6.486468e+04
# min                                          5.670000e+02
# 25%                                          3.779000e+03
# 50%                                          5.648000e+03
# 75%                                          1.098700e+04
# max                                          1.107833e+06
#
#         Lifetime Post reach by people who like your Page  \
# count                                         421.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                         6118.539192
# std                                          7845.941764
# min                                           236.000000
# 25%                                          2110.000000
# 50%                                          3136.000000
# 75%                                          5696.000000
# max                                         51456.000000
#
#         Lifetime People who have liked your Page and engaged with your post  \
# count                                          421.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           510.964371
# std                                            400.796595
# min                                              9.000000
# 25%                                            305.000000
# 50%                                            403.000000
# 75%                                            570.000000
# max                                           3430.000000
#
#            comment         like       share  Total Interactions
# count   421.000000   421.000000  421.000000          421.000000
# unique         NaN          NaN         NaN                 NaN
# top            NaN          NaN         NaN                 NaN
# freq           NaN          NaN         NaN                 NaN
# mean      7.581948   184.066508   27.156770          218.805226
# std      22.641009   346.542549   44.973104          407.568504
# min       0.000000     0.000000    0.000000            0.000000
# 25%       1.000000    58.000000   10.000000           72.000000
# 50%       3.000000   101.000000   19.000000          124.000000
# 75%       7.000000   187.000000   32.000000          226.000000
# max     372.000000  5172.000000  790.000000         6334.000000

# %%
photo_subset["Paid"].unique()
# Out:
# array([0., 1.])

# %%
# Counting number of paid and unpaid posts
sns.countplot(x=dataset["Paid"])
plt.show()

# %% [markdown]
# ## Transpose of data

# %%
# Shape of data before transposing
print("Shape of Video subset : ", video_subset.shape)
# Out:
# Shape of Video subset :  (7, 19)

# %%
# Transposing data
video_subset_transpose = video_subset.transpose()

# %%
# Shape of data after transposing
print("Shape of Video subset transpose: ", video_subset_transpose.shape)
# Out:
# Shape of Video subset transpose:  (19, 7)

# %%
video_subset_transpose
# Out:
#                                                        29      55      71   \
# Page total likes                                    138895  138329  137893
# Type                                                 Video   Video   Video
# Category                                                 1       1       1
# Post Month                                              12      11      11
# Post Weekday                                             4       6       5
# Post Hour                                               11       2       3
# Paid                                                   1.0     1.0     1.0
# Lifetime Post Total Reach                            36208   16416  100768
# Lifetime Post Total Impressions                      61262   31950  220447
# Lifetime Engaged Users                                1141     459    2101
# Lifetime Post Consumers                               1068     411    1735
# Lifetime Post Consumptions                            1728     539    2331
# Lifetime Post Impressions by people who have li...   30131   21436   59658
# Lifetime Post reach by people who like your Page     14112    9568   18880
# Lifetime People who have liked your Page and en...     559     363     885
# comment                                                 18       2      17
# like                                                 143.0    65.0   449.0
# share                                                 13.0    14.0    84.0
# Total Interactions                                     174      81     550
#
#                                                        74      183     243  \
# Page total likes                                    137893  134879  130791
# Type                                                 Video   Video   Video
# Category                                                 1       1       1
# Post Month                                              11       9       7
# Post Weekday                                             3       2       3
# Post Hour                                               11      10      11
# Paid                                                   0.0     0.0     1.0
# Lifetime Post Total Reach                            13544   30624   21872
# Lifetime Post Total Impressions                      30235   56950   40413
# Lifetime Engaged Users                                 517    2080    3872
# Lifetime Post Consumers                                458    1956    3822
# Lifetime Post Consumptions                             667    3253    7327
# Lifetime Post Impressions by people who have li...   26622   32033   24667
# Lifetime Post reach by people who like your Page     11760   15744   12920
# Lifetime People who have liked your Page and en...     447    1376    2218
# comment                                                  2       6      18
# like                                                  99.0   345.0   315.0
# share                                                 13.0   121.0    76.0
# Total Interactions                                     114     472     409
#
#                                                        277
# Page total likes                                    126424
# Type                                                 Video
# Category                                                 1
# Post Month                                               6
# Post Weekday                                             2
# Post Hour                                               13
# Paid                                                   0.0
# Lifetime Post Total Reach                           139008
# Lifetime Post Total Impressions                     277100
# Lifetime Engaged Users                                1779
# Lifetime Post Consumers                               1643
# Lifetime Post Consumptions                            2356
# Lifetime Post Impressions by people who have li...  107502
# Lifetime Post reach by people who like your Page     38720
# Lifetime People who have liked your Page and en...    1008
# comment                                                 23
# like                                                 204.0
# share                                                 44.0
# Total Interactions                                     271

# %% [markdown]
# ## Merging data

# %%
print("Shape of photo subset : ", photo_subset.shape)
print("Shape of video subset : ", video_subset.shape)
# Out:
# Shape of photo subset :  (421, 19)
# Shape of video subset :  (7, 19)

# %%
# Checking columns of both data subsets
print("Columns of photo subset : ", photo_subset.columns)
print("Columns of video subset : ", video_subset.columns)
# Out:
# Columns of photo subset :  Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')
# Columns of video subset :  Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
# Merging the 2 subsets (DataFrames)
photo_video_merged = pd.merge(
    left=photo_subset,
    right=video_subset,
    on="Paid"
)

# %%
photo_video_merged.head()
# Out:
#    Page total likes_x Type_x  Category_x  Post Month_x  Post Weekday_x  \
# 0              139441  Photo           2            12               4
# 1              139441  Photo           2            12               4
# 2              139441  Photo           2            12               4
# 3              139441  Photo           3            12               3
# 4              139441  Photo           3            12               3
#
#    Post Hour_x  Paid  Lifetime Post Total Reach_x  \
# 0            3   0.0                         2752
# 1            3   0.0                         2752
# 2            3   0.0                         2752
# 3            3   0.0                         2413
# 4            3   0.0                         2413
#
#    Lifetime Post Total Impressions_x  Lifetime Engaged Users_x  ...  \
# 0                               5091                       178  ...
# 1                               5091                       178  ...
# 2                               5091                       178  ...
# 3                               4373                       177  ...
# 4                               4373                       177  ...
#
#    Lifetime Engaged Users_y  Lifetime Post Consumers_y  \
# 0                       517                        458
# 1                      2080                       1956
# 2                      1779                       1643
# 3                       517                        458
# 4                      2080                       1956
#
#    Lifetime Post Consumptions_y  \
# 0                           667
# 1                          3253
# 2                          2356
# 3                           667
# 4                          3253
#
#    Lifetime Post Impressions by people who have liked your Page_y  \
# 0                                              26622
# 1                                              32033
# 2                                             107502
# 3                                              26622
# 4                                              32033
#
#    Lifetime Post reach by people who like your Page_y  \
# 0                                              11760
# 1                                              15744
# 2                                              38720
# 3                                              11760
# 4                                              15744
#
#    Lifetime People who have liked your Page and engaged with your post_y  \
# 0                                                447
# 1                                               1376
# 2                                               1008
# 3                                                447
# 4                                               1376
#
#    comment_y  like_y  share_y  Total Interactions_y
# 0          2    99.0     13.0                   114
# 1          6   345.0    121.0                   472
# 2         23   204.0     44.0                   271
# 3          2    99.0     13.0                   114
# 4          6   345.0    121.0                   472
#
# [5 rows x 37 columns]

# %%
photo_video_merged.shape
# Out:
# (1382, 37)

# %% [markdown]
# ## Sorting data

# %%
# Sorting the data on the basis of number of likes
likes_sorted_data = dataset.sort_values(by="Page total likes")

# %%
# Displaying the top 5 liked records
likes_sorted_data.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 498             81370  Photo         3           1             4         11
# 497             81370  Photo         1           1             5          2
# 496             81370  Photo         2           1             5          8
# 493             85093  Photo         3           1             1          2
# 495             85093  Photo         3           1             7          2
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 498   0.0                       4156                             7564
# 497   0.0                       3778                             7216
# 496   0.0                       3480                             6229
# 493   0.0                       8412                            13960
# 495   0.0                       4684                             7536
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 498                     626                      574
# 497                     625                      572
# 496                     537                      508
# 493                    1179                     1111
# 495                     733                      708
#
#      Lifetime Post Consumptions  \
# 498                         832
# 497                         795
# 496                         687
# 493                        1632
# 495                         985
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 498                                               4534
# 497                                               4742
# 496                                               3961
# 493                                               8632
# 495                                               4750
#
#      Lifetime Post reach by people who like your Page  \
# 498                                              2452
# 497                                              2388
# 496                                              2104
# 493                                              5348
# 495                                              2876
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 498                                                370
# 497                                                363
# 496                                                301
# 493                                                699
# 495                                                392
#
#      comment   like  share  Total Interactions
# 498        7   91.0   38.0                 136
# 497        4   93.0   18.0                 115
# 496        0   53.0   22.0                  75
# 493       17  185.0   55.0                 257
# 495        5   53.0   26.0                  84

# %%
# Displaying the bottom 10 liked records
likes_sorted_data.tail(10)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 4             139441   Photo         2          12             2          3
# 6             139441   Photo         3          12             1          3
# 12            139441   Photo         2          12             5         10
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# 11            139441   Photo         2          12             5         10
# 13            139441   Photo         2          12             5          3
# 7             139441   Photo         3          12             7          9
# 0             139441   Photo         2          12             4          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 4    0.0                       7244                            13594
# 6    1.0                      11692                            19479
# 12   0.0                       2847                             5133
# 8    0.0                      11844                            22538
# 9    0.0                       4694                             8668
# 10   0.0                      21744                            42334
# 11   0.0                       3112                             5590
# 13   0.0                       2549                             4896
# 7    1.0                      13720                            24137
# 0    0.0                       2752                             5091
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# 4                      671                      410
# 6                      481                      265
# 12                     193                      115
# 8                     1530                     1407
# 9                      280                      183
# 10                    4258                     4100
# 11                     208                      127
# 13                     249                      134
# 7                      537                      232
# 0                      178                      109
#
#     Lifetime Post Consumptions  \
# 4                          580
# 6                          364
# 12                         133
# 8                         1692
# 9                          250
# 10                        4540
# 11                         145
# 13                         168
# 7                          305
# 0                          159
#
#     Lifetime Post Impressions by people who have liked your Page  \
# 4                                                6228
# 6                                               15432
# 12                                               3779
# 8                                               15220
# 9                                                4309
# 10                                              37849
# 11                                               3887
# 13                                               3631
# 7                                               19728
# 0                                                3078
#
#     Lifetime Post reach by people who like your Page  \
# 4                                               3200
# 6                                               9328
# 12                                              2072
# 8                                               7912
# 9                                               2324
# 10                                             18952
# 11                                              2174
# 13                                              1917
# 7                                              11056
# 0                                               1640
#
#     Lifetime People who have liked your Page and engaged with your post  \
# 4                                                 396
# 6                                                 379
# 12                                                152
# 8                                                1250
# 9                                                 199
# 10                                               3798
# 11                                                165
# 13                                                183
# 7                                                 422
# 0                                                 119
#
#     comment   like  share  Total Interactions
# 4        19  325.0   49.0                 393
# 6         3  249.0   27.0                 279
# 12        0   90.0   14.0                 104
# 8         0  161.0   31.0                 192
# 9         3  113.0   26.0                 142
# 10        0  233.0   19.0                 252
# 11        0   88.0   18.0                 106
# 13        5  137.0   10.0                 152
# 7         0  325.0   14.0                 339
# 0         4   79.0   17.0                 100

# %% [markdown]
# ## Reshaping the data
#
# ### Melting

# %%
# Melting the data on the value variables as type and category
melting_result = pd.melt(
    frame=dataset,
    id_vars="Page total likes",
    value_vars=["Type", "Category"]
)

# %%
melting_result.head()
# Out:
#    Page total likes variable   value
# 0            139441     Type   Photo
# 1            139441     Type  Status
# 2            139441     Type   Photo
# 3            139441     Type   Photo
# 4            139441     Type   Photo

# %%
melting_result.tail()
# Out:
#      Page total likes  variable value
# 985             85093  Category     3
# 986             85093  Category     3
# 987             81370  Category     2
# 988             81370  Category     1
# 989             81370  Category     3

# %%
# Checking shape of melted data
melting_result.shape
# Out:
# (990, 3)
